# %%
print(128989)
# Out:
# 128989

# %%
# !where jupyter
# Out:
# d:\OneDrive\4.数据分析\VS code\day01\.venv\Scripts\jupyter.exe
# D:\software\Anaconda\Scripts\jupyter.exe

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.2.0
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.0
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.60.2
# fqdn                      1.5.1
# h11                       0.16.0
# ...

# %%
import sys
print(sys.executable)
# Out:
# d:\OneDrive\4.数据分析\VS code\day01\.venv\Scripts\python.exe
